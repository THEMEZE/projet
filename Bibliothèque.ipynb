# %%
import os
import fitz  # PyMuPDF
import pandas as pd

# Chemin vers le répertoire contenant les livres PDF
dossier_livres = '/Users/themezeguillaume/Desktop/Documents_Clef/Livres_vacances'

# Dictionnaire pour stocker les thèmes et les livres correspondants
livres_par_theme = {}

# Parcourir tous les fichiers PDF dans le répertoire
for fichier in os.listdir(dossier_livres):
    if fichier.endswith('.pdf'):
        chemin_pdf = os.path.join(dossier_livres, fichier)
        try:
            # Ouvrir le fichier PDF
            document = fitz.open(chemin_pdf)
            
            # Lire le titre (première page)
            titre = document.metadata.get('title', 'Titre inconnu')
            
            # Lire d'autres métadonnées ou contenu pour identifier le thème
            # Par exemple, rechercher des mots clés dans le texte ou les métadonnées

            # Stocker le livre sous le thème correspondant
            # Par exemple, supposons que le thème soit basé sur le titre ou les métadonnées
            theme = 'Physique classique'  # À remplacer par votre logique de catégorisation
            
            if theme not in livres_par_theme:
                livres_par_theme[theme] = []
            livres_par_theme[theme].append(titre)
            
            # Fermer le document PDF
            document.close()
            
        except Exception as e:
            print(f"Erreur lors du traitement du fichier {fichier}: {str(e)}")

# Enregistrer les résultats dans un fichier texte
with open('livres_par_theme.txt', 'w', encoding='utf-8') as f:
    for theme, livres in livres_par_theme.items():
        f.write(f"{theme}:\n")
        for livre in livres:
            f.write(f"  - {livre}\n")
        f.write("\n")

# Enregistrer les résultats dans un fichier CSV (optionnel)
df = pd.DataFrame([(theme, livre) for theme, livres in livres_par_theme.items() for livre in livres], columns=['Thème', 'Livre'])
df.to_csv('livres_par_theme.csv', index=False, encoding='utf-8')

print("Classification des livres terminée. Fichiers créés : livres_par_theme.txt, livres_par_theme.csv")
# Out:
# Classification des livres terminée. Fichiers créés : livres_par_theme.txt, livres_par_theme.csv

# %%
import os
import fitz  # PyMuPDF
import pandas as pd

# Chemin vers le répertoire contenant les livres PDF
dossier_livres = '/Users/themezeguillaume/Desktop/Documents_Clef/Livres_vacances'

# Dictionnaire pour stocker les thèmes et les livres correspondants
livres_par_theme = {}

# Parcourir tous les fichiers PDF dans le répertoire
for fichier in os.listdir(dossier_livres):
    if fichier.endswith('.pdf'):
        chemin_pdf = os.path.join(dossier_livres, fichier)
        try:
            # Ouvrir le fichier PDF
            document = fitz.open(chemin_pdf)
            
            # Lire le titre (première page)
            titre = document.metadata.get('title', 'Titre inconnu')
            
            # Lire d'autres métadonnées ou contenu pour identifier le thème
            # Par exemple, rechercher des mots clés dans le texte ou les métadonnées

            # Stocker le livre sous le thème correspondant
            # Par exemple, supposons que le thème soit basé sur le titre ou les métadonnées
            theme = 'Physique classique'  # À remplacer par votre logique de catégorisation
            
            if theme not in livres_par_theme:
                livres_par_theme[theme] = []
            livres_par_theme[theme].append(titre)
            
            # Afficher le thème et le titre du livre
            print(f"Thème: {theme}, Livre: {titre}")
            
            # Fermer le document PDF
            document.close()
            
        except Exception as e:
            print(f"Erreur lors du traitement du fichier {fichier}: {str(e)}")

# Enregistrer les résultats dans un fichier texte
with open('livres_par_theme.txt', 'w', encoding='utf-8') as f:
    for theme, livres in livres_par_theme.items():
        f.write(f"{theme}:\n")
        for livre in livres:
            f.write(f"  - {livre}\n")
        f.write("\n")

# Enregistrer les résultats dans un fichier CSV (optionnel)
df = pd.DataFrame([(theme, livre) for theme, livres in livres_par_theme.items() for livre in livres], columns=['Thème', 'Livre'])
df.to_csv('livres_par_theme.csv', index=False, encoding='utf-8')

print("Classification des livres terminée. Fichiers créés : livres_par_theme.txt, livres_par_theme.csv")
# Out:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: 0198566735.pdf
# Thème: Physique classique, Livre: Hydrodynamique physique
# Thème: Physique classique, Livre: Processus d'interaction entre photons et atomes
# Thème: Physique classique, Livre: Physique statistique - 3ème édition
# Thème: Physique classique, Livre: Physique statistique hors d'équilibre - Processus irréversibles linéaires
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: Physique quantique
# Thème: Physique classique, Livre: Cours d'optique ondulatoire – femto-physique.fr
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: Physique des plasmas
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: Un soupçon de théorie des groupes: groupe des rotations et groupe de Poincaré
# Thème: Physique classique, Livre: Microsoft Word - puits et barrières de potentiel.doc
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: Abrégé de mécanique quantique pour l'agrégation de physique
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: Mécanique quantique - Tome I
# Thème: Physique classique, Livre: Abrégé de mécanique quantique pour l'agrégation de physique
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: E:/TEX/Bouquin-tome-III/Tome-III-complet-dimension-livre-final/Tome-3-MQ-livre.dvi
# Thème: Physique classique, Livre: Mécanique quantique - Tome II
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: U:\NC\EDP\book\ONL\title\title.dvi
# Thème: Physique classique, Livre: Introductory Quantum Optics
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre:
# Thème: Physique classique, Livre: Physique mésoscopique des électrons et des photons
# Thème: Physique classique, Livre: Physique. Tout-en-un MP | MP*
# Thème: Physique classique, Livre:
# Classification des livres terminée. Fichiers créés : livres_par_theme.txt, livres_par_theme.csv

# %%
import os

# Obtenir le chemin du répertoire courant
current_directory = os.getcwd()
print(current_directory)
current_directory = current_directory + '/Documents_Clef/Livres_vacances'
print(current_directory)
# Lister les dossiers dans le répertoire courant
folders = [d for d in os.listdir(current_directory) if os.path.isdir(os.path.join(current_directory, d))]

# Afficher les dossiers
for folder in folders:
    print(folder)
# Out:
# /Users/themezeguillaume/Desktop
# /Users/themezeguillaume/Desktop/Documents_Clef/Livres_vacances

# %%
import os

# Définir la structure du projet
project_name = "your_project_directory"
folders = ["venv"]
files = {
    "requirements.txt": "PyMuPDF\npandas\n",
    "classify_books.py": """import os
import fitz  # PyMuPDF
import pandas as pd

# Chemin vers le répertoire contenant les livres PDF
dossier_livres = '/Users/themezeguillaume/Desktop/Documents_Clef/Livres_vacances'

# Dictionnaire pour stocker les thèmes et les livres correspondants
livres_par_theme = {}

# Parcourir tous les fichiers PDF dans le répertoire
for fichier in os.listdir(dossier_livres):
    if fichier.endswith('.pdf'):
        chemin_pdf = os.path.join(dossier_livres, fichier)
        try:
            # Ouvrir le fichier PDF
            document = fitz.open(chemin_pdf)
            
            # Lire le titre (première page)
            titre = document.metadata.get('title', 'Titre inconnu')
            
            # Lire d'autres métadonnées ou contenu pour identifier le thème
            # Par exemple, rechercher des mots clés dans le texte ou les métadonnées

            # Stocker le livre sous le thème correspondant
            # Par exemple, supposons que le thème soit basé sur le titre ou les métadonnées
            theme = 'Physique classique'  # À remplacer par votre logique de catégorisation
            
            if theme not in livres_par_theme:
                livres_par_theme[theme] = []
            livres_par_theme[theme].append(titre)
            
            # Afficher le thème et le titre du livre
            print(f"Thème: {theme}, Livre: {titre}")
            
            # Fermer le document PDF
            document.close()
            
        except Exception as e:
            print(f"Erreur lors du traitement du fichier {fichier}: {str(e)}")

# Enregistrer les résultats dans un fichier texte
with open('livres_par_theme.txt', 'w', encoding='utf-8') as f:
    for theme, livres in livres_par_theme.items():
        f.write(f"{theme}:\n")
        for livre in livres:
            f.write(f"  - {livre}\n")
        f.write("\\n")

# Enregistrer les résultats dans un fichier CSV (optionnel)
df = pd.DataFrame([(theme, livre) for theme, livres in livres_par_theme.items() for livre in livres], columns=['Thème', 'Livre'])
df.to_csv('livres_par_theme.csv', index=False, encoding='utf-8')

print("Classification des livres terminée. Fichiers créés : livres_par_theme.txt, livres_par_theme.csv")
""",
    "README.md": """# Classification de Livres PDF par Thème

## Installation

1. Exécutez le script de configuration :

    ```sh
    ./setup.sh
    ```

2. Pour activer l'environnement virtuel après l'installation :

    - Sur macOS/Linux :

      ```sh
      source venv/bin/activate
      ```

    - Sur Windows :

      ```sh
      venv\\Scripts\\activate
      ```

## Utilisation

1. Placez vos fichiers PDF dans le répertoire spécifié dans le script (`dossier_livres`).
2. Exécutez le script :

    ```sh
    python classify_books.py
    ```

3. Les résultats seront enregistrés dans `livres_par_theme.txt` et `livres_par_theme.csv`.

## Mise à jour des dépendances

Pour ajouter de nouvelles dépendances ou mettre à jour les existantes, modifiez votre environnement virtuel puis mettez à jour `requirements.txt` :

```sh
pip freeze > requirements.txt
""",
    "setup.sh": """#!/bin/bash

# Détecter l'OS
OS="`uname`"
case $OS in
  'Linux')
    OS='Linux'
    ;;
  'Darwin') 
    OS='Mac'
    ;;
  'CYGWIN'* | 'MINGW32'* | 'MSYS'* | 'MINGW'*) 
    OS='Windows'
    ;;
  *) 
    OS='unknown'
    ;;
esac

# Créer et activer l'environnement virtuel
if [ $OS == 'Windows' ]; then
  python -m venv venv
  source venv/Scripts/activate
else
  python3 -m venv venv
  source venv/bin/activate
fi

# Installer les dépendances
pip install --upgrade pip
pip install -r requirements.txt

# Initialiser un dépôt Git local
git init

# Ajouter tous les fichiers et faire un premier commit
git add .
git commit -m "Initial commit"

# Demander l'URL du dépôt distant
read -p "Entrez l'URL du dépôt Git distant : " repo_url

# Ajouter le dépôt distant et pousser le commit initial
git remote add origin $repo_url
git branch -M main
git push -u origin main

echo "L'environnement virtuel est créé, les dépendances sont installées, et le dépôt Git est configuré."
echo "Pour activer l'environnement virtuel, utilisez :"
if [ $OS == 'Windows' ]; then
  echo "venv\\Scripts\\activate"
else
  echo "source venv/bin/activate"
fi
"""
}

# Créer la structure du projet
if not os.path.exists(project_name):
    os.makedirs(project_name)

for folder in folders:
    folder_path = os.path.join(project_name, folder)
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

for file_name, file_content in files.items():
    file_path = os.path.join(project_name, file_name)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(file_content)

# Rendre le script setup.sh exécutable
setup_sh_path = os.path.join(project_name, "setup.sh")
os.chmod(setup_sh_path, 0o755)

print(f"Structure du projet {project_name} créée avec succès.")
# Out:
# Structure du projet your_project_directory créée avec succès.
